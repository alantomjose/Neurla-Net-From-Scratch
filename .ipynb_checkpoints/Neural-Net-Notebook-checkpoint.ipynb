# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from Neural_net import NeuralNet

# %%
iris = pd.read_csv("./Iris.csv")

# %%
iris = iris.sample(frac=1).reset_index(drop=True)

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
X = iris[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
X = np.array(X)

# %%
y = iris.Species

# %%
encoder =  OneHotEncoder(sparse=False)
y = encoder.fit_transform(np.array(y).reshape(-1,1))

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15)
X_train,X_val,y_train,y_val = train_test_split(X,y,test_size=0.15)

# %%
nn=NeuralNet()

# %%
weights = nn.InitializeWeights([3,3,4,5])
#w=InitializeWeights([3,4,3])
# Out:
# Theta1 1 is (3, 4)
# Theta1 2 is (4, 4)
# Theta1 3 is (5, 5)

# %%
def sigmoid(z):
    z=1.0/(1.0+np.exp(-z))

# %%
def forewardPropagation(x,weigts,numofl):
    activation = [x]
    nodes = x
    for i in range(numofl):
        a = sigmoid(weights[i].dot(nodes.T))
        activation.append(a)
        nodes=a
        print(a)
    return activation

# %%
forewardPropagation(X_train,weights,4)
# Out:
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-520da664efd0> in <module>
# ----> 1 forewardPropagation(X_train,weights,4)
#
# <ipython-input-20-3808ff97bfd5> in forewardPropagation(x, weigts, numofl)
#       3     nodes = x
#       4     for i in range(numofl):
# ----> 5         a = sigmoid(weights[i].dot(nodes.T))
#       6         activation.append(a)
#       7         nodes=a
#
# AttributeError: 'NoneType' object has no attribute 'T'

# %%
weights[0].dot(X_train.T)
# Out:
# array([[ -1.80993918,  -1.65969362,  -1.83201377,  -1.8017433 ,
#          -4.8717801 ,  -2.16466592,  -4.77650933,  -1.6204369 ,
#          -3.40389013,  -4.06110698,  -3.94314002,  -6.18456208,
#          -4.30382021,  -5.52313016,  -4.228448  ,  -1.9772184 ,
#          -4.47463713,  -5.10889173,  -4.6877527 ,  -3.98310959,
#          -5.56542882,  -1.41706705,  -4.93916585,  -1.94848207,
#          -5.7447377 ,  -1.79319558,  -5.73896216,  -5.95083968,
#          -1.79823651,  -4.23460941,  -3.64497798,  -2.27219459,
#          -3.73969265,  -1.94379299,  -1.87820656,  -5.29642135,
#          -1.61271045,  -3.93308905,  -4.60580999,  -1.67755313,
#          -4.32580813,  -1.38871806,  -4.80958289,  -4.3651049 ,
#          -1.85026061,  -3.41594465,  -5.45321107,  -4.30803529,
#          -4.04486828,  -3.77267495,  -4.27460988,  -3.98314049,
#          -1.68413277,  -4.60454562,  -5.75715323,  -1.69232407,
#          -5.16828585,  -3.76566136,  -1.99077616,  -5.5816721 ,
# ...
